# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 876.6/876.6 kB 26.4 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QhXt19AjBOoA7OWHglmz")
project = rf.workspace("nasser-alqeifi").project("kothen")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
root_dir='/content/Köthen-2/data.yaml'

# %%
from ultralytics.models.yolo.segment import SegmentationTrainer

args = dict(model="yolov8n-seg.pt", data=root_dir, epochs=10)
trainer = SegmentationTrainer(overrides=args)
trainer.train()
# Out:
# Ultralytics 8.3.17 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image, display

# %%
# !yolo task= segment mode= val model= '/content/runs/segment/train/weights/best.pt' data= '/content/Köthen-2/data.yaml'
# Out:
# Ultralytics 8.3.17 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3,261,184 parameters, 0 gradients, 12.0 GFLOPs
# val: Scanning /content/Köthen-2/valid/labels.cache... 201 images, 0 backgrounds, 0 corrupt: 100% 201/201 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 13/13 [00:07<00:00,  1.74it/s]
#                    all        201       1172      0.655      0.519      0.538      0.389      0.635      0.496      0.511      0.365
#           Bicycle lane         21         24      0.664      0.625      0.632      0.561      0.668      0.625      0.619      0.511
#                Manhole         22         29      0.905      0.379       0.54      0.298      0.826      0.345      0.519      0.318
# ...

# %%
Image(f'/content/runs/segment/train/confusion_matrix_normalized.png')

# %%
Image(f'/content/runs/segment/train/results.png')

# %%
Image(f'/content/runs/segment/train/val_batch2_pred.jpg')

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !yolo task=segment mode=predict model='/content/runs/segment/train/weights/best.pt' data=root_dir source= '/content/Köthen-2/test/images'
# Out:
# Ultralytics 8.3.17 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3,261,184 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/2 /content/Köthen-2/test/images/Purpose and Applicability.jpg: 640x640 3 Persons, 1 Vehicle, 2 grasss, 1 sidewalk, 12.4ms
# image 2/2 /content/Köthen-2/test/images/pexels-jimmy-teoh-1634279.jpg.jpg: 448x640 5 Persons, 4 Vehicles, 1 sidewalk, 43.0ms
# Speed: 3.3ms preprocess, 27.7ms inference, 333.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob

for image_path in glob.glob(f'/content/runs/segment/predict/*.jpg'):
  display(Image(filename=image_path,height=600))
  print('/n')
# Out:
# /n
# /n
